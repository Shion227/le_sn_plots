# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import ticker
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

# %%
cc_en = np.load('shion_data/shion_energy_distribution_cc.npy')[0]
cc_weight = np.load('shion_data/shion_energy_distribution_cc.npy')[1]
es_en = np.load('shion_data/shion_energy_distribution_es.npy')[0]
es_weight = np.load('shion_data/shion_energy_distribution_es.npy')[1]

# %%
stack_v_true_e_reco = plt.figure(figsize=(8,6))
plt.hist([cc_en, es_en], bins = 500, stacked=True, weights=[cc_weight, es_weight], label=['CC','ES'])
plt.xlim(0, 50)
plt.ylabel('Event per 0.1 MeV')
plt.xlabel('Energy [MeV]');
plt.title('Energy Distribution')
plt.show()
