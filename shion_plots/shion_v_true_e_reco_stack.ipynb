# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib import ticker
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

# %%
cc_v_true_e_reco = np.load('shion_data/shion_v_true_e_reco_stack_cc.npy')[0]
weightcc = np.load('shion_data/shion_v_true_e_reco_stack_cc.npy')[1]
es_v_true_e_reco = np.load('shion_data/shion_v_true_e_reco_stack_es.npy')[0]
weightes = np.load('shion_data/shion_v_true_e_reco_stack_es.npy')[1]

# %%
v_true_e_reco_stack = plt.figure(figsize=(8,6))
plt.hist([cc_v_true_e_reco, es_v_true_e_reco], bins = 40, stacked=True, weights=[weightcc, weightes])
plt.ylim(0, 100)
plt.xlim(-1, 1)
plt.ylabel('Event per 0.05 rad')
plt.xlabel('Cos');
plt.title('v_true_e_true')
plt.show()
